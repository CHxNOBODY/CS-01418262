# %%
import pandas as pd

# %%
df_house = pd.read_csv("2_house_price.csv")
df_house
# Out:
#        Unnamed: 0       property       price                    location  \
# 0               0           Flat  10000000.0                        G-10
# 1               1           Flat   6900000.0                        E-11
# 2               2          House  16500000.0                        G-15
# 3               3          House  43500000.0                   Bani Gala
# 4               4          House   7000000.0                 DHA Defence
# ...           ...            ...         ...                         ...
# 61066       99457          House  40000000.0                 DHA Defence
# 61067       99470  Upper Portion     25000.0               Chak 208 Road
# 61068       99477          House  41500000.0                       NFC 1
# 61069       99482          House  22500000.0  State Life Housing Society
# 61070       99490          House  14000000.0         Bahria Town Karachi
#
#              city  baths   purpose  bedrooms  area
# ...

# %%
df_house.iloc[12:20]
# Out:
#     Unnamed: 0 property       price     location       city  baths   purpose  \
# 12          12    House  26900000.0         B-17  Islamabad      6  For Sale
# 13          13    House   4500000.0   Bhara kahu  Islamabad      3  For Sale
# 14          14    House   4500000.0  Garden Town  Islamabad      4  For Sale
# 15          15    House   6800000.0   Koral Town  Islamabad      4  For Sale
# 16          16    House  20000000.0  Soan Garden  Islamabad      5  For Sale
# 17          17     Flat  19400000.0    Blue Area  Islamabad      1  For Sale
# 18          18     Flat   8000000.0         G-11  Islamabad      2  For Sale
# 19          19     Flat   6300000.0         E-11  Islamabad      3  For Sale
#
#     bedrooms  area
# 12         6  20.0
# 13         3   5.0
# 14         4   4.7
# 15         4   4.0
# 16         6  12.0
# 17         1   4.3
# 18         2   6.7
# 19         3   5.3

# %%
df_house.sample()

# .sample use to random the data
# Out:
#        Unnamed: 0       property      price location    city  baths   purpose  \
# 27115       32207  Upper Portion  1700000.0     Eden  Lahore      1  For Sale
#
#        bedrooms  area
# 27115         2   3.0

# %%
df_house.sample(n=100)

# random 100 sample
# Out:
#        Unnamed: 0       property       price                  location  \
# 55406       84215          House    300000.0                       F-6
# 8488         9270  Upper Portion     55000.0                Wapda City
# 51441       73859           Flat   4700000.0            Federal B Area
# 21573       24825          House   9800000.0           Taj Bagh Scheme
# 4768         5188          House   7350000.0                     Cantt
# ...           ...            ...         ...                       ...
# 57507       89292          House  13000000.0       Bahria Town Karachi
# 43318       57181           Flat   6500000.0    Bahria Town Rawalpindi
# 30180       36455           Flat   5200000.0                 Azam Town
# 18256       20655          House   5500000.0  Marghzar Officers Colony
# 43014       56615          House    280000.0                       F-8
#
#              city  baths   purpose  bedrooms  area
# 55406   Islamabad      5  For Rent         4  26.0
# ...

# %%
df_house["city"].value_counts(normalize=True)

# add normalize to calculate in percent
# Out:
# city
# Karachi       0.357584
# Islamabad     0.249627
# Lahore        0.236184
# Rawalpindi    0.122661
# Faisalabad    0.033944
# Name: proportion, dtype: float64

# %%
df_house["city"].value_counts().plot(kind="bar")

# plot graph in bar form
# Out:
# <Axes: xlabel='city'>

# %%
df_simple_random = df_house.sample(n=100, random_state=1234)
df_simple_random
# Out:
#        Unnamed: 0 property       price             location        city  \
# 276           300    House  11000000.0          Bahria Town      Lahore
# 58592       91903    House  15500000.0          DHA Defence   Islamabad
# 21640       24910    House   3500000.0           Gadap Town     Karachi
# 55505       84499    House   9500000.0  UET Housing Society      Lahore
# 44757       59754    House  37500000.0                 G-13   Islamabad
# ...           ...      ...         ...                  ...         ...
# 22913       26569    House    175000.0                  F-7   Islamabad
# 16515       18504    House  24500000.0           Johar Town      Lahore
# 25421       29899     Flat  16000000.0         Jamshed Town     Karachi
# 56439       86666    House  10000000.0              GT Road      Lahore
# 39236       50186    House     50000.0          Adiala Road  Rawalpindi
#
#        baths   purpose  bedrooms  area
# 276        3  For Sale         3   5.0
# ...

# %%
df_simple_random["city"].value_counts()
# Out:
# city
# Islamabad     33
# Karachi       31
# Lahore        19
# Rawalpindi    12
# Faisalabad     5
# Name: count, dtype: int64

# %%
df_house["city"].value_counts()
# Out:
# city
# Karachi       21838
# Islamabad     15245
# Lahore        14424
# Rawalpindi     7491
# Faisalabad     2073
# Name: count, dtype: int64

# %%
df_simple_random = df_house.sample(frac=0.1, random_state=42)
df_simple_random
# Out:
#        Unnamed: 0       property       price             location        city  \
# 11541       12640           Flat     40000.0    Islamabad Highway   Islamabad
# 41807       54476           Flat   3150000.0       Federal B Area     Karachi
# 55783       85172          House  29000000.0            Scheme 33     Karachi
# 29303       35152  Upper Portion     35000.0                 G-11   Islamabad
# 46603       63213           Flat  12500000.0  Bahria Town Karachi     Karachi
# ...           ...            ...         ...                  ...         ...
# 2296         2498          House  14000000.0            Samanabad      Lahore
# 17104       19218          House  35000000.0       Satellite Town  Rawalpindi
# 43222       56986          House  11000000.0           Izmir Town      Lahore
# 15607       17414          House   6500000.0           Gadap Town     Karachi
# 23623       27502          House  25500000.0            Scheme 33     Karachi
#
# ...

# %%
# %pip install -q scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\khaop\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

# %%
unused, df_house_stratified = train_test_split(df_house, test_size=0.1, stratify=df_house["city"], random_state=123)
df_house_stratified

# noted in python we can use "_" to say that variable that not use
# Out:
#        Unnamed: 0       property       price  \
# 39854       51184          House     22000.0
# 53145       78450          House  15500000.0
# 25503       30023          House  12000000.0
# 16864       18926          House  16000000.0
# 42500       55705           Flat     52000.0
# ...           ...            ...         ...
# 12138       13331          House  25500000.0
# 38798       49459          House  11000000.0
# 2399         2612          House    139000.0
# 30189       36468           Flat  15000000.0
# 45216       60576  Lower Portion     48000.0
#
#                                          location        city  baths  \
# 39854                      Bahria Town Rawalpindi  Rawalpindi      2
# 53145                  State Life Housing Society      Lahore      5
# 25503                                   Islampura      Lahore      4
# 16864                                         I-9   Islamabad      6
# 42500                                     Clifton     Karachi      2
# ...

# %%
df_house["city"].value_counts(normalize=True)
# Out:
# city
# Karachi       0.357584
# Islamabad     0.249627
# Lahore        0.236184
# Rawalpindi    0.122661
# Faisalabad    0.033944
# Name: proportion, dtype: float64

# %%
df_simple_random["city"].value_counts(normalize=True)
# Out:
# city
# Karachi       0.365810
# Islamabad     0.250860
# Lahore        0.234649
# Rawalpindi    0.118389
# Faisalabad    0.030293
# Name: proportion, dtype: float64

# %%
df_house_stratified["city"].value_counts(normalize=True)
# Out:
# city
# Karachi       0.357564
# Islamabad     0.249673
# Lahore        0.236248
# Rawalpindi    0.122626
# Faisalabad    0.033890
# Name: proportion, dtype: float64

# %%
df_house
# Out:
#        Unnamed: 0       property       price                    location  \
# 0               0           Flat  10000000.0                        G-10
# 1               1           Flat   6900000.0                        E-11
# 2               2          House  16500000.0                        G-15
# 3               3          House  43500000.0                   Bani Gala
# 4               4          House   7000000.0                 DHA Defence
# ...           ...            ...         ...                         ...
# 61066       99457          House  40000000.0                 DHA Defence
# 61067       99470  Upper Portion     25000.0               Chak 208 Road
# 61068       99477          House  41500000.0                       NFC 1
# 61069       99482          House  22500000.0  State Life Housing Society
# 61070       99490          House  14000000.0         Bahria Town Karachi
#
#              city  baths   purpose  bedrooms  area
# ...

# %%
expensive_price = df_house["price"].quantile(0.4)
expensive_price
# Out:
# np.float64(4500000.0)

# %%
def label_expensive(row):
    if row["price"] > expensive_price:
        return 1
    else:
        return 0
    
    # also we can write in this way
    # return 1 if row["price"] > expensive_price else 0
    
df_house["is_expensive"] = df_house.apply(label_expensive, axis=1)  # axis use to defind what do we want pandas to do with column
#  df_house["is_expensive"] = df_house.apply(lambda row: 1 if row["price"] > expensive_price else 0, axis=1)
df_house
# Out:
#        Unnamed: 0       property       price                    location  \
# 0               0           Flat  10000000.0                        G-10
# 1               1           Flat   6900000.0                        E-11
# 2               2          House  16500000.0                        G-15
# 3               3          House  43500000.0                   Bani Gala
# 4               4          House   7000000.0                 DHA Defence
# ...           ...            ...         ...                         ...
# 61066       99457          House  40000000.0                 DHA Defence
# 61067       99470  Upper Portion     25000.0               Chak 208 Road
# 61068       99477          House  41500000.0                       NFC 1
# 61069       99482          House  22500000.0  State Life Housing Society
# 61070       99490          House  14000000.0         Bahria Town Karachi
#
#              city  baths   purpose  bedrooms  area  is_expensive
# ...

# %%
df_house["is_expensive"].value_counts()
# Out:
# is_expensive
# 1    36234
# 0    24837
# Name: count, dtype: int64

# %%
df_house["is_expensive"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='is_expensive'>

# %%
# %pip install -q openpyxl

df_complaints = pd.read_excel("complaints.xlsx")
df_complaints
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\khaop\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#       เลขรับ กปม.     เลขหนังสือ ลงวันที่\n(คีย์เป็นเลข)  \
# 0           812.0   สผ 0001/6925              2021-05-31
# 1             NaN   สผ 0001/9215              2020-09-21
# 2           558.0   สผ 0001/2468              2022-03-01
# 3          2174.0  สผ 0025/11287              2022-09-23
# 4             NaN    สว 0001/377              2021-01-29
# ...           ...            ...                     ...
# 2151       1508.0   สผ 0001/7115              2022-06-27
# 2152        149.0    สผ 0001/257              2022-01-18
# 2153          NaN   สผ 0001/9215              2020-09-21
# 2154          NaN   สผ 0001/9221              2020-09-21
# ...

# %%
df_complaints.describe
# Out:
# <bound method NDFrame.describe of       เลขรับ กปม.     เลขหนังสือ ลงวันที่\n(คีย์เป็นเลข)  \
# 0           812.0   สผ 0001/6925              2021-05-31
# 1             NaN   สผ 0001/9215              2020-09-21
# 2           558.0   สผ 0001/2468              2022-03-01
# 3          2174.0  สผ 0025/11287              2022-09-23
# 4             NaN    สว 0001/377              2021-01-29
# ...           ...            ...                     ...
# 2151       1508.0   สผ 0001/7115              2022-06-27
# 2152        149.0    สผ 0001/257              2022-01-18
# 2153          NaN   สผ 0001/9215              2020-09-21
# 2154          NaN   สผ 0001/9221              2020-09-21
# 2155          NaN    สว 0001/377              2021-01-29
#
#      วันที่รับเรื่อง\n(คีย์เป็นเลข)  ปีที่  สมัยสามัญ\nครั้งที่  ครั้งที่  \
# 0                        2021-06-21    NaN                  NaN       NaN
# 1                        2020-09-24    2.0                  1.0      18.0
# ...

# %%
df_complaints.info
# Out:
# <bound method DataFrame.info of       เลขรับ กปม.     เลขหนังสือ ลงวันที่\n(คีย์เป็นเลข)  \
# 0           812.0   สผ 0001/6925              2021-05-31
# 1             NaN   สผ 0001/9215              2020-09-21
# 2           558.0   สผ 0001/2468              2022-03-01
# 3          2174.0  สผ 0025/11287              2022-09-23
# 4             NaN    สว 0001/377              2021-01-29
# ...           ...            ...                     ...
# 2151       1508.0   สผ 0001/7115              2022-06-27
# 2152        149.0    สผ 0001/257              2022-01-18
# 2153          NaN   สผ 0001/9215              2020-09-21
# 2154          NaN   สผ 0001/9221              2020-09-21
# 2155          NaN    สว 0001/377              2021-01-29
#
#      วันที่รับเรื่อง\n(คีย์เป็นเลข)  ปีที่  สมัยสามัญ\nครั้งที่  ครั้งที่  \
# 0                        2021-06-21    NaN                  NaN       NaN
# 1                        2020-09-24    2.0                  1.0      18.0
# ...

# %%
df_complaints.columns
# Out:
# Index(['เลขรับ กปม.', 'เลขหนังสือ', 'ลงวันที่\n(คีย์เป็นเลข)',
#        'วันที่รับเรื่อง\n(คีย์เป็นเลข)', 'ปีที่', 'สมัยสามัญ\nครั้งที่',
#        'ครั้งที่', 'วันที่ประชุม / เรื่องร้องเรียนมา (คีย์เป็นเลข)', 'ประเภท',
#        'ชื่อผู้ร้องเรียน', 'ประเภทบุคคล (Auto)', 'พรรคการเมือง',
#        'ส.ส. เขต / บัญชีรายชื่อ\n(Auto)', 'ประเด็นที่ร้องเรียน',
#        'หมวดหมู่ปัญหา (เลือก)', 'พื้นที่ / ภูมิภาค', 'จำนวนส่ง\n(Auto)',
#        'เจ้าของเรื่อง', 'ข้อพิจารณา\n(เลือก)', 'หน่วยงาน\nที่เกี่ยวข้อง',
#        'รอง นรม. / รมต.นร. ที่กำกับการดำเนินการ',
#        'วันที่แจ้งบัญชา\n(คีย์เป็นเลข)', 'เลขหนังสือ\nแจ้งหน่วยงาน',
#        'Deadline ติดตาม\n(Auto)', 'การติดตาม\n(Auto)', 'สถานะ\n(Auto)',
#        'การทวง', 'เลขที่หนังสือ\n/ลงวันที่', 'วันที่รับ\nหนังสือตอบกลับ',
#        'สถานะคำตอบ\n(เลือก)', 'เลขหนังสือ\nตอบสภาฯ', 'วิเคราะห์คำตอบ', 'คำตอบ',
#        'วันที่ปิดเรื่อง\n(ตอบสภา)\n(คีย์เป็นเลข)', 'Unnamed: 34', 'หมายเหตุ',
#        'การ Update', 'ชื่อ-สกุลผู้ร้อง'],
# ...

# %%
# ประเด็นที่ร้องเรียน

def label_urgent(row):
    if "ด่วน" in str(row["ประเด็นที่ร้องเรียน"]):
        return 1
    else:
        return 0
    
df_complaints["is_urgent"] = df_complaints.apply(label_urgent, axis=1)
df_complaints
# Out:
#       เลขรับ กปม.     เลขหนังสือ ลงวันที่\n(คีย์เป็นเลข)  \
# 0           812.0   สผ 0001/6925              2021-05-31
# 1             NaN   สผ 0001/9215              2020-09-21
# 2           558.0   สผ 0001/2468              2022-03-01
# 3          2174.0  สผ 0025/11287              2022-09-23
# 4             NaN    สว 0001/377              2021-01-29
# ...           ...            ...                     ...
# 2151       1508.0   สผ 0001/7115              2022-06-27
# 2152        149.0    สผ 0001/257              2022-01-18
# 2153          NaN   สผ 0001/9215              2020-09-21
# 2154          NaN   สผ 0001/9221              2020-09-21
# 2155          NaN    สว 0001/377              2021-01-29
#
#      วันที่รับเรื่อง\n(คีย์เป็นเลข)  ปีที่  สมัยสามัญ\nครั้งที่  ครั้งที่  \
# 0                        2021-06-21    NaN                  NaN       NaN
# 1                        2020-09-24    2.0                  1.0      18.0
# ...

# %%
df_house["is_expensive"].value_counts()
# Out:
# is_expensive
# 1    36234
# 0    24837
# Name: count, dtype: int64

# %%
df_complaints["is_urgent"].value_counts()
# Out:
# is_urgent
# 0    1975
# 1     181
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=123)
_, df_house_over = ros.fit_resample(df_house, df_house["is_expensive"])
df_house_over.value_counts()
# Out:
# is_expensive
# 1    36234
# 0    36234
# Name: count, dtype: int64

# %%
from pathlib import Path

df_images = {"image_path": [], "label": []}

for dir in Path("./cats_vs_dogs").iterdir():
    for path in dir.glob("*"):
        df_images["image_path"].append(path)
        df_images["label"].append(dir.name)
        
df_images = pd.DataFrame.from_dict(df_images)
df_images
# Out:
#                     image_path label
# 0       cats_vs_dogs\cat\0.jpg   cat
# 1       cats_vs_dogs\cat\1.jpg   cat
# 2      cats_vs_dogs\cat\10.jpg   cat
# 3     cats_vs_dogs\cat\100.jpg   cat
# 4     cats_vs_dogs\cat\101.jpg   cat
# ...                        ...   ...
# 1872  cats_vs_dogs\dog\995.jpg   dog
# 1873  cats_vs_dogs\dog\996.jpg   dog
# 1874  cats_vs_dogs\dog\997.jpg   dog
# 1875  cats_vs_dogs\dog\998.jpg   dog
# 1876  cats_vs_dogs\dog\999.jpg   dog
#
# [1877 rows x 2 columns]

# %%
from PIL import Image

image_random = df_images.sample(n=1, random_state=123)["image_path"].iloc[0]
image_random = Image.open(image_random).convert("RGB")
image_random
# Out:
# <PIL.Image.Image image mode=RGB size=500x375>

# %%
image_random.transpose(Image.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375>

# %%
image_random.transpose(Image.FLIP_TOP_BOTTOM)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375>

# %%
image_random.rotate(20)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375>

# %%
import numpy as np

img_array = np.array(image_random)
noise = np.random.uniform(0, 50, img_array.shape).astype("uint8")
image_noise = np.clip(img_array + noise, 0, 255)
image_noise = Image.fromarray(image_noise.astype(np.uint8))
image_noise
# Out:
# <PIL.Image.Image image mode=RGB size=500x375>

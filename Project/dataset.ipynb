# %%
import pandas as pd

data = pd.read_csv("youtube_data.csv")
data
# Out:
#         video_id                                              title  \
# 0    gsJAlLOFBv0                      TINY Tech That Actually Works
# 1    ypicIkaiViM  AI & future of workforce: Andrew Yang on how t...
# 2    1Nef8LPO-jo       5 ILLEGAL gadgets that will get you ARRESTED
# 3    lCHqmzynO-s                      Overrated vs. Underrated Tech
# 4    7uFrtqSwYzM  APPLE Glass Revolutionizes AR Experience Forever!
# ..           ...                                                ...
# 595  jWiV4bWsDl4  Puse a prueba estos rayos x para ver a traves ...
# 596  pGtMbnxaXs8  Old Tech That Still Works  #facts #sciencefact...
# 597  2DaOJ1a0AYg  iPhone lene vale ho to ruk jao #smartphone #s2...
# 598  aO5HE6Q0jaM  Programming memes 😂 sub for more 🖥️👾#tech #tec...
# 599  Ukb8U5Ku4gA  Amazing Power Full Tractor Work In The Field  ...
#
#                                            description        published_date  \
# ...

# %%
mushroom = pd.read_csv("test.csv")
mushroom
# Out:
#                                               image_path  \
# 0      /kaggle/working/merged_dataset/Xanthoria parie...
# 1      /kaggle/working/merged_dataset/Paxillus involu...
# 2      /kaggle/working/merged_dataset/Lactarius tormi...
# 3      /kaggle/working/merged_dataset/Tylopilus felle...
# 4      /kaggle/working/merged_dataset/Amanita rubesce...
# ...                                                  ...
# 15609  /kaggle/working/merged_dataset/Amanita velosa/...
# 15610  /kaggle/working/merged_dataset/Crucibulum laev...
# 15611  /kaggle/working/merged_dataset/Schizophyllum c...
# 15612  /kaggle/working/merged_dataset/Ganoderma appla...
# 15613  /kaggle/working/merged_dataset/Hypomyces lacti...
#
#                         label
# 0         Xanthoria parietina
# 1          Paxillus involutus
# 2        Lactarius torminosus
# 3           Tylopilus felleus
# 4           Amanita rubescens
# ...                       ...
# 15609          Amanita velosa
# ...

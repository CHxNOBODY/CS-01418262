# %%
# import pandas as pd

# data = pd.read_csv("youtube_data.csv")
# data

# %%
import pandas as pd

mushroom = pd.read_csv("test.csv")
mushroom.head(n=60)
# Out:
#                                            image_path  \
# 0   /kaggle/working/merged_dataset/Xanthoria parie...
# 1   /kaggle/working/merged_dataset/Paxillus involu...
# 2   /kaggle/working/merged_dataset/Lactarius tormi...
# 3   /kaggle/working/merged_dataset/Tylopilus felle...
# 4   /kaggle/working/merged_dataset/Amanita rubesce...
# 5   /kaggle/working/merged_dataset/Coprinopsis atr...
# 6   /kaggle/working/merged_dataset/Vulpicida pinas...
# 7   /kaggle/working/merged_dataset/Parmelia sulcat...
# 8   /kaggle/working/merged_dataset/Armillaria mell...
# 9   /kaggle/working/merged_dataset/Rhytisma acerin...
# 10  /kaggle/working/merged_dataset/Amanita muscari...
# 11  /kaggle/working/merged_dataset/Parmelia sulcat...
# 12  /kaggle/working/merged_dataset/Chondrostereum ...
# 13  /kaggle/working/merged_dataset/Lycoperdon perl...
# 14  /kaggle/working/merged_dataset/Amanita calyptr...
# 15  /kaggle/working/merged_dataset/Bjerkandera adu...
# ...

# %%
mushroom2 = pd.read_csv("train.csv")
mushroom2["label"].value_counts()
# Out:
# label
# Lycoperdon perlatum            4080
# Chlorociboria aeruginascens    4080
# Amanita muscaria               4080
# Xanthoria parietina            4080
# Coprinellus micaceus           4080
#                                ...
# Agaricus augustus              4080
# Mutinus ravenelii              4080
# Trametes betulina              4080
# Gymnopilus luteofolius         4080
# Coprinopsis atramentaria       4080
# Name: count, Length: 169, dtype: int64

# %%
mushroom2.head()
# Out:
#                                           image_path  \
# 0  /kaggle/working/merged_dataset/Lycoperdon perl...
# 1  /kaggle/working/merged_dataset/Chlorociboria a...
# 2  /kaggle/working/merged_dataset/Amanita muscari...
# 3  /kaggle/working/merged_dataset/Xanthoria parie...
# 4  /kaggle/working/merged_dataset/Coprinellus mic...
#
#                          label
# 0          Lycoperdon perlatum
# 1  Chlorociboria aeruginascens
# 2             Amanita muscaria
# 3          Xanthoria parietina
# 4         Coprinellus micaceus

# %%
mushroom2.tail()
# Out:
#                                                image_path               label
# 689515  /kaggle/working/merged_dataset/Vulpicida pinas...  Vulpicida pinastri
# 689516  /kaggle/working/merged_dataset/Vulpicida pinas...  Vulpicida pinastri
# 689517  /kaggle/working/merged_dataset/Vulpicida pinas...  Vulpicida pinastri
# 689518  /kaggle/working/merged_dataset/Vulpicida pinas...  Vulpicida pinastri
# 689519  /kaggle/working/merged_dataset/Vulpicida pinas...  Vulpicida pinastri

# %%
mushroom.describe()
# Out:
#                                                image_path                label
# count                                               15614                15614
# unique                                              15614                  169
# top     /kaggle/working/merged_dataset/Hypomyces lacti...  Xanthoria parietina
# freq                                                    1                  874

# %%
mushroom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15614 entries, 0 to 15613
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  15614 non-null  object
#  1   label       15614 non-null  object
# dtypes: object(2)
# memory usage: 244.1+ KB

# %%
mushroom.dtypes
# Out:
# image_path    object
# label         object
# dtype: object

# %%
from IPython.display import Image, display

for idx, row in mushroom.iterrows():
    # Change 'image_path' to the actual column name in your CSV
    display(Image(filename=row['image_path'], width=200))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 5
#       1 from IPython.display import Image, display
#       3 for idx, row in mushroom.iterrows():
#       4     # Change 'image_path' to the actual column name in your CSV
# ----> 5     display(Image(filename=row['image_path'], width=200))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\display.py:1053, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1051 self.unconfined = unconfined
#    1052 self.alt = alt
# -> 1053 super(Image, self).__init__(data=data, url=url, filename=filename,
#    1054         metadata=metadata)
#    1056 if self.width is None and self.metadata.get('width', {}):
#    1057     self.width = metadata['width']
#
# ...
